# %%
# eLDAon
# https://www.kaggle.com/code/errearanhas/topic-modelling-lda-on-elon-tweets/notebook

# %%
#!pip install MLB-StatsAPI

# %%
import statsapi # https://betterprogramming.pub/intro-to-mlb-stats-api-part-2-f47564651d01
import logging

# %%
sched = statsapi.schedule(start_date='07/01/2018',end_date='07/31/2018',team=143,opponent=121)

# %% [raw]
# logger = logging.getLogger('statsapi')
# logger.setLevel(logging.DEBUG)
# rootLogger = logging.getLogger()
# rootLogger.setLevel(logging.DEBUG)
# ch = logging.StreamHandler()
# formatter = logging.Formatter("%(asctime)s - %(levelname)8s - %(name)s(%(thread)s) - %(message)s")
# ch.setFormatter(formatter)
# rootLogger.addHandler(ch)

# %%
statsapi.lookup_player('Anthony Gose')
# Out:
# [{'id': 543238,
#   'fullName': 'Anthony Gose',
#   'firstName': 'Anthony',
#   'lastName': 'Gose',
#   'primaryNumber': '26',
#   'currentTeam': {'id': 114},
#   'primaryPosition': {'code': '1', 'abbreviation': 'P'},
#   'useName': 'Anthony',
#   'boxscoreName': 'Gose',
#   'mlbDebutDate': '2012-07-17',
#   'nameFirstLast': 'Anthony Gose',
#   'firstLastName': 'Anthony Gose',
#   'lastFirstName': 'Gose, Anthony',
#   'lastInitName': 'Gose, A',
#   'initLastName': 'A Gose',
#   'fullFMLName': 'Anthony Robert Gose',
#   'fullLFMName': 'Gose, Anthony Robert'}]

# %%
statsapi.lookup_team('114')
# Out:
# [{'id': 114,
#   'name': 'Cleveland Guardians',
#   'teamCode': 'cle',
#   'fileCode': 'cle',
#   'teamName': 'Guardians',
#   'locationName': 'Cleveland',
#   'shortName': 'Cleveland'}]

# %%
statsapi.schedule() # historical data. . . p up to date
# Out:
# [{'game_id': 662385,
#   'game_datetime': '2022-05-11T16:35:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Los Angeles Dodgers',
#   'home_name': 'Pittsburgh Pirates',
#   'away_id': 119,
#   'home_id': 134,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Dillon Peters',
#   'away_probable_pitcher': 'Ryan Pepiot',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 3,
#   'home_score': 5,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'venue_id': 31,
#   'venue_name': 'PNC Park',
#   'winning_team': 'Pittsburgh Pirates',
#   'losing_team': 'Los Angeles Dodgers',
#   'winning_pitcher': 'Wil Crowe',
#   'losing_pitcher': 'Daniel Hudson',
#   'save_pitcher': 'David Bednar',
#   'summary': '2022-05-11 - Los Angeles Dodgers (3) @ Pittsburgh Pirates (5) (Final)'},
#  {'game_id': 661300,
#   'game_datetime': '2022-05-11T16:35:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Toronto Blue Jays',
#   'home_name': 'New York Yankees',
#   'away_id': 141,
#   'home_id': 147,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Jameson Taillon',
#   'away_probable_pitcher': 'Jose Berrios',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 3,
#   'home_score': 5,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'venue_id': 3313,
#   'venue_name': 'Yankee Stadium',
#   'winning_team': 'New York Yankees',
#   'losing_team': 'Toronto Blue Jays',
#   'winning_pitcher': 'Jameson Taillon',
#   'losing_pitcher': 'Jose Berrios',
#   'save_pitcher': 'Aroldis Chapman',
#   'summary': '2022-05-11 - Toronto Blue Jays (3) @ New York Yankees (5) (Final)'},
#  {'game_id': 663074,
#   'game_datetime': '2022-05-11T16:35:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Milwaukee Brewers',
#   'home_name': 'Cincinnati Reds',
#   'away_id': 158,
#   'home_id': 113,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Vladimir Gutierrez',
#   'away_probable_pitcher': 'Adrian Houser',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 11,
#   'home_score': 14,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'venue_id': 2602,
#   'venue_name': 'Great American Ball Park',
#   'winning_team': 'Cincinnati Reds',
#   'losing_team': 'Milwaukee Brewers',
#   'winning_pitcher': 'Alexis Diaz',
#   'losing_pitcher': 'Adrian Houser',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - Milwaukee Brewers (11) @ Cincinnati Reds (14) (Final)'},
#  {'game_id': 662176,
#   'game_datetime': '2022-05-11T19:40:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Philadelphia Phillies',
#   'home_name': 'Seattle Mariners',
#   'away_id': 143,
#   'home_id': 136,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Logan Gilbert',
#   'away_probable_pitcher': 'Bailey Falter',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 4,
#   'home_score': 2,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 680,
#   'venue_name': 'T-Mobile Park',
#   'winning_team': 'Philadelphia Phillies',
#   'losing_team': 'Seattle Mariners',
#   'winning_pitcher': 'Seranthony Dominguez',
#   'losing_pitcher': 'Logan Gilbert',
#   'save_pitcher': 'Corey Knebel',
#   'summary': '2022-05-11 - Philadelphia Phillies (4) @ Seattle Mariners (2) (Final)'},
#  {'game_id': 663358,
#   'game_datetime': '2022-05-11T19:40:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Miami Marlins',
#   'home_name': 'Arizona Diamondbacks',
#   'away_id': 146,
#   'home_id': 109,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Merrill Kelly',
#   'away_probable_pitcher': 'Sandy Alcantara',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 11,
#   'home_score': 3,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 15,
#   'venue_name': 'Chase Field',
#   'winning_team': 'Miami Marlins',
#   'losing_team': 'Arizona Diamondbacks',
#   'winning_pitcher': 'Anthony Bass',
#   'losing_pitcher': 'Mark Melancon',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - Miami Marlins (11) @ Arizona Diamondbacks (3) (Final)'},
#  {'game_id': 662095,
#   'game_datetime': '2022-05-11T19:45:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Colorado Rockies',
#   'home_name': 'San Francisco Giants',
#   'away_id': 115,
#   'home_id': 137,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Alex Cobb',
#   'away_probable_pitcher': 'Chad Kuhl',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 1,
#   'home_score': 7,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'venue_id': 2395,
#   'venue_name': 'Oracle Park',
#   'winning_team': 'San Francisco Giants',
#   'losing_team': 'Colorado Rockies',
#   'winning_pitcher': 'Alex Cobb',
#   'losing_pitcher': 'Chad Kuhl',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - Colorado Rockies (1) @ San Francisco Giants (7) (Final)'},
#  {'game_id': 662273,
#   'game_datetime': '2022-05-11T20:10:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Chicago Cubs',
#   'home_name': 'San Diego Padres',
#   'away_id': 112,
#   'home_id': 135,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Nick Martinez',
#   'away_probable_pitcher': 'Keegan Thompson',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 7,
#   'home_score': 5,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 2680,
#   'venue_name': 'Petco Park',
#   'winning_team': 'Chicago Cubs',
#   'losing_team': 'San Diego Padres',
#   'winning_pitcher': 'Mychal Givens',
#   'losing_pitcher': 'Luis Garcia',
#   'save_pitcher': 'Rowan Wick',
#   'summary': '2022-05-11 - Chicago Cubs (7) @ San Diego Padres (5) (Final)'},
#  {'game_id': 662526,
#   'game_datetime': '2022-05-11T23:05:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'New York Mets',
#   'home_name': 'Washington Nationals',
#   'away_id': 121,
#   'home_id': 120,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Aaron Sanchez',
#   'away_probable_pitcher': 'Tylor Megill',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 3,
#   'home_score': 8,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'venue_id': 3309,
#   'venue_name': 'Nationals Park',
#   'winning_team': 'Washington Nationals',
#   'losing_team': 'New York Mets',
#   'winning_pitcher': 'Aaron Sanchez',
#   'losing_pitcher': 'Tylor Megill',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - New York Mets (3) @ Washington Nationals (8) (Final)'},
#  {'game_id': 663450,
#   'game_datetime': '2022-05-11T23:07:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Tampa Bay Rays',
#   'home_name': 'Los Angeles Angels',
#   'away_id': 139,
#   'home_id': 108,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Shohei Ohtani',
#   'away_probable_pitcher': 'Shane McClanahan',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 4,
#   'home_score': 2,
#   'current_inning': 10,
#   'inning_state': 'Bottom',
#   'venue_id': 1,
#   'venue_name': 'Angel Stadium',
#   'winning_team': 'Tampa Bay Rays',
#   'losing_team': 'Los Angeles Angels',
#   'winning_pitcher': 'J.P. Feyereisen',
#   'losing_pitcher': 'Aaron Loup',
#   'save_pitcher': 'Brooks Raley',
#   'summary': '2022-05-11 - Tampa Bay Rays (4) @ Los Angeles Angels (2) (Final)'},
#  {'game_id': 662873,
#   'game_datetime': '2022-05-11T23:10:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Oakland Athletics',
#   'home_name': 'Detroit Tigers',
#   'away_id': 133,
#   'home_id': 116,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Joey Wentz',
#   'away_probable_pitcher': 'Zach Logue',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 9,
#   'home_score': 0,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 2394,
#   'venue_name': 'Comerica Park',
#   'winning_team': 'Oakland Athletics',
#   'losing_team': 'Detroit Tigers',
#   'winning_pitcher': 'Zach Logue',
#   'losing_pitcher': 'Joey Wentz',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - Oakland Athletics (9) @ Detroit Tigers (0) (Final)'},
#  {'game_id': 661548,
#   'game_datetime': '2022-05-11T23:20:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Boston Red Sox',
#   'home_name': 'Atlanta Braves',
#   'away_id': 111,
#   'home_id': 144,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Ian Anderson',
#   'away_probable_pitcher': 'Nathan Eovaldi',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 3,
#   'home_score': 5,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 4705,
#   'venue_name': 'Truist Park',
#   'winning_team': 'Atlanta Braves',
#   'losing_team': 'Boston Red Sox',
#   'winning_pitcher': 'Kenley Jansen',
#   'losing_pitcher': 'Ryan Brasier',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - Boston Red Sox (3) @ Atlanta Braves (5) (Final)'},
#  {'game_id': 661702,
#   'game_datetime': '2022-05-11T23:40:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Suspended: Rain',
#   'away_name': 'Houston Astros',
#   'home_name': 'Minnesota Twins',
#   'away_id': 117,
#   'home_id': 142,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Chris Archer',
#   'away_probable_pitcher': 'Jose Urquidy',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 5,
#   'home_score': 1,
#   'current_inning': 4,
#   'inning_state': 'Top',
#   'venue_id': 3312,
#   'venue_name': 'Target Field',
#   'summary': '2022-05-11 - Houston Astros @ Minnesota Twins (Suspended: Rain)'},
#  {'game_id': 662006,
#   'game_datetime': '2022-05-11T23:45:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Baltimore Orioles',
#   'home_name': 'St. Louis Cardinals',
#   'away_id': 110,
#   'home_id': 138,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Miles Mikolas',
#   'away_probable_pitcher': 'Spenser Watkins',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 1,
#   'home_score': 10,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'venue_id': 2889,
#   'venue_name': 'Busch Stadium',
#   'winning_team': 'St. Louis Cardinals',
#   'losing_team': 'Baltimore Orioles',
#   'winning_pitcher': 'Miles Mikolas',
#   'losing_pitcher': 'Spenser Watkins',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - Baltimore Orioles (1) @ St. Louis Cardinals (10) (Final)'},
#  {'game_id': 661899,
#   'game_datetime': '2022-05-12T00:05:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Kansas City Royals',
#   'home_name': 'Texas Rangers',
#   'away_id': 118,
#   'home_id': 140,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Matt Bush',
#   'away_probable_pitcher': 'Gabe Speier',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 8,
#   'home_score': 2,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 5325,
#   'venue_name': 'Globe Life Field',
#   'winning_team': 'Kansas City Royals',
#   'losing_team': 'Texas Rangers',
#   'winning_pitcher': 'Joel Payamps',
#   'losing_pitcher': 'Kolby Allard',
#   'save_pitcher': None,
#   'summary': '2022-05-11 - Kansas City Royals (8) @ Texas Rangers (2) (Final)'},
#  {'game_id': 661523,
#   'game_datetime': '2022-05-11T18:10:00Z',
#   'game_date': '2022-05-11',
#   'game_type': 'R',
#   'status': 'Postponed',
#   'away_name': 'Cleveland Guardians',
#   'home_name': 'Chicago White Sox',
#   'away_id': 114,
#   'home_id': 145,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Vince Velasquez',
#   'away_probable_pitcher': 'Aaron Civale',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': '0',
#   'home_score': '0',
#   'current_inning': '',
#   'inning_state': '',
#   'venue_id': 4,
#   'venue_name': 'Guaranteed Rate Field',
#   'summary': '2022-05-11 - Cleveland Guardians @ Chicago White Sox (Postponed)'}]

# %%
statsapi.player_stat_data('Vince Velasquez')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/ry/gtypcvm50js8j8wlbz5z7h6m0000gn/T/ipykernel_3769/3139569885.py in <module>
# ----> 1 statsapi.player_stat_data('Vince Velasquez')
#
# /opt/anaconda3/lib/python3.7/site-packages/statsapi/__init__.py in player_stat_data(personId, group, type)
#    1118         "hydrate": "stats(group=" + group + ",type=" + type + "),currentTeam",
#    1119     }
# -> 1120     r = get("person", params)
#    1121
#    1122     stat_groups = []
#
# /opt/anaconda3/lib/python3.7/site-packages/statsapi/__init__.py in get(endpoint, params, force)
#    1666     r = requests.get(url)
#    1667     if r.status_code not in [200, 201]:
# -> 1668         r.raise_for_status()
#    1669     else:
#    1670         return r.json()
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     958
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#     962     def close(self):
#
# HTTPError: 400 Client Error: Bad Request for url: https://statsapi.mlb.com/api/v1/people/Vince%20Velasquez?hydrate=stats(group=%5Bhitting,pitching,fielding%5D,type=season),currentTeam
